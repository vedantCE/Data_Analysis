# %%
pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("matches.csv")

# %%
df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
df['city'].isnull().sum()
# Out:
# np.int64(51)

# %%
df2=df.copy()

# %%
df2.head()

# %%
df2[pd.isnull(df2.city)]
# pd.isnull(dataframe['column_name']) is a Pandas function used to detect missing or null values (NaN, None, NaT) within a specific column of a DataFrame.

# %%
df.city.fillna("Ahmedabad")
# df2.columnName.fillna("Unknown") is a Python code snippet used in the pandas library for data analysis. It fills missing values (NaN or None) in a specific column of a DataFrame with the text "Unknown".
# Out:
# 0        Bangalore
# 1       Chandigarh
# 2            Delhi
# 3           Mumbai
# 4          Kolkata
#            ...
# 1090     Hyderabad
# 1091     Ahmedabad
# 1092     Ahmedabad
# 1093       Chennai
# 1094       Chennai
# Name: city, Length: 1095, dtype: object

# %%
df["city"].max
# Out:
# <bound method Series.max of 0        Bangalore
# 1       Chandigarh
# 2            Delhi
# 3           Mumbai
# 4          Kolkata
#            ...
# 1090     Hyderabad
# 1091     Ahmedabad
# 1092     Ahmedabad
# 1093       Chennai
# 1094       Chennai
# Name: city, Length: 1095, dtype: object>

# %%
df2["city"].replace("Not Specify","Bangalore")

# %%
df2.isnull().sum()
