# %%
import pandas as pd

# %%
df=pd.read_csv("P1_Exe.csv")

# %%
df.head(3)
# Out:
#     Name  Age  Marks
# 0   Amit   20     85
# 1   Neha   19     90
# 2  Rahul   21     78

# %%
df.tail(2)
# Out:
#     Name  Age  Marks
# 3  Pooja   20     88
# 4  Krish   22     92

# %%
df.shape
# Out:
# (5, 3)

# %%
df.shape[0]
# Out:
# 5

# %%
df.shape[1]
# Out:
# 3

# %%
df.rename(columns={"Name":"Student"},inplace=True)
print(df)
# Out:
#   Student  Age  Marks
# 0    Amit   20     85
# 1    Neha   19     90
# 2   Rahul   21     78
# 3   Pooja   20     88
# 4   Krish   22     92
