# %%
import pandas as pd
import numpy as np

# %%
data=[1,2,3,4]
ser=pd.Series(data)
print(ser)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
Data=np.array(['g','e','e','k','s','f','o','r','g','e','e','k','s'])
ser=pd.Series(data)
# This line creates a pandas Series named ser from the NumPy array Data. A Series is a one-dimensional labeled array in pandas, like a single column in a spreadsheet.
# By default, pandas automatically assigns a numeric index starting from 0 to each element in the series.
print(ser)
print(ser[:2]) # start from index 0 to 1 dont include index 2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# 0    1
# 1    2
# dtype: int64
