# %%
#in pandas datafram.dtypesto check data types
# df.describe() thi summary male

import pandas as pd

df=pd.read_csv("weather_data_1.csv",header=None)
header=["date","temperature","wind speed","weather"]
df.columns=header
df = df.dropna(subset=['temperature', 'wind speed', 'weather'])
# Jo row in teen columns me se kisi bhi ek me NaN/NA rakhta hai, wo row drop (delete) ho jayegi (default behavior how='any' hota hai)
print(df)
# df.describe(include="all")
# df.info()
# Out:
#          date  temperature  wind speed weather
# 0  01-01-2019         37.0         6.0    Rain
# 1  02-01-2019         35.0         7.0   Sunny
# 2  03-01-2019         38.0         2.0    Snow
# 3  04-01-2019         34.0         7.0    Snow
# 4  05-01-2019         32.0         4.0    Rain
# 5  06-01-2019         31.0         2.0   Sunny
