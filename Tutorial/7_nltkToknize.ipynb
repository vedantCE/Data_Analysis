# %%
pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in /opt/homebrew/lib/python3.11/site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /opt/homebrew/lib/python3.11/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/lib/python3.11/site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (from nltk) (4.67.1)
# Using cached nltk-3.9.2-py3-none-any.whl (1.5 MB)
# Installing collected packages: nltk
# Successfully installed nltk-3.9.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import required libraries
import nltk
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Download required NLTK resources (run once)
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/vedantbhatt/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/vedantbhatt/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Sample input text
text = "NLTK is a powerful library! It processes text, removes numbers like 123, symbols %, and stop words."

# %%
# Step 1: Convert text to lowercase
text = text.lower()
print(text)
# Out:
# nltk is a powerful library! it processes text, removes numbers like 123, symbols %, and stop words.

# %%
# Step 2: Remove numbers
text = re.sub(r'\d+', '', text)
print(text)
# Out:
# nltk is a powerful library! it processes text, removes numbers like , symbols %, and stop words.

# %%
# Step 3: Remove symbols and special characters
text = re.sub(r'[^\w\s]', '', text)
print(text)
# Out:
# nltk is a powerful library it processes text removes numbers like  symbols  and stop words

# %%
# Step 4: Tokenize text
tokens = word_tokenize(text)
print(text)
# Out:
# nltk is a powerful library it processes text removes numbers like  symbols  and stop words

# %%
# Step 5: Remove stop words
stop_words = set(stopwords.words('english'))
print(stop_words)
filtered_tokens = [word for word in tokens if word not in stop_words]
print(filtered_tokens)
# Out:
# {'we', 'an', 'for', "it'd", 'that', 'hadn', 'as', 'then', 'themselves', "you've", 'during', "shan't", "they'd", 'herself', 'those', 'through', "we'll", 'their', 'do', 'just', 'mightn', 'wasn', 'did', 'who', "i'd", "weren't", 'over', "she'll", 'here', 'don', 'what', 'which', "aren't", 'further', 're', "she'd", "wasn't", 'weren', 'having', 'm', 'own', 'between', "you're", 'shan', 'had', 'i', 'me', 'on', 'needn', "doesn't", 'than', 'ma', 'from', 'with', 'mustn', 'how', 'll', 'when', "shouldn't", "wouldn't", 'while', 'before', 'it', 'be', 'ain', 's', 'below', 'at', 'the', 'whom', 'theirs', 'isn', 'very', 'shouldn', 'didn', 'ours', 'himself', 'against', 'there', 'him', "mightn't", 'd', "they'll", 'not', 'our', 'been', 'haven', 'your', 'about', "i've", 'once', 'so', "haven't", "we've", "don't", "hadn't", "should've", 'doing', 'y', 'some', 'too', 'am', 'but', "we're", 'no', 'being', 'he', 'other', 'to', "he'll", 'nor', 'has', "isn't", 'you', 'is', 'couldn', 'down', 'where', 'will', "that'll", "won't", "they're", 'out', 'up', "he's", "it'll", 'his', 'above', "she's", "we'd", 'into', 'because', 'myself', 't', "didn't", 'does', 'until', 'won', 'each', 'more', 'why', 'my', 'now', 'o', "they've", "needn't", 'only', 'or', 'this', 'wouldn', 'off', 'if', 'doesn', "you'll", "couldn't", 'itself', 'all', 'and', 'most', 'in', 'was', "you'd", 'aren', 'a', 'her', 'yourself', 'yours', 'after', "i'm", 'any', "it's", 'of', 'ourselves', 'few', 'these', 'were', 'by', 'such', 'again', 'should', 'hers', "mustn't", "he'd", 'same', 'can', 'yourselves', "i'll", "hasn't", 'have', 'they', 'hasn', 've', 'its', 'them', 'under', 'she', 'are', 'both'}
# ['nltk', 'powerful', 'library', 'processes', 'text', 'removes', 'numbers', 'like', 'symbols', 'stop', 'words']

# %%
# Output
print("Original Text:")
print(text)
# Out:
# Original Text:
# nltk is a powerful library it processes text removes numbers like  symbols  and stop words

# %%
print("\nTokens after preprocessing:")
print(filtered_tokens)
# Out:
# Tokens after preprocessing:
# ['nltk', 'powerful', 'library', 'processes', 'text', 'removes', 'numbers', 'like', 'symbols', 'stop', 'words']
