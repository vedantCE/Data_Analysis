# %%
#read csv --> read_csv()
# print --> direct its ofject df
# df.head(n) -->how first n row of data frame by default first 5 pront kare 
# df.tail(n) -->how bottom n row of data frame by default last 5 pront kare 
# replace default head by df.columns=header
# Out:
#             0   1  2      3
# 0  01-01-2019  37  6   Rain
# 1  02-01-2019  35  7  Sunny
# 2  03-01-2019  38  2   Snow
# 3  04-01-2019  34  7   Snow
# 4  05-01-2019  32  4   Rain
# 5  06-01-2019  31  2  Sunny

# %%
import pandas as pd
df=pd.read_csv("weather_data_1.csv",header=None) # reading of csv
# print(df) # df to print data
# print(df.head(3))
header=["date","temperature","wind speed","weather"]
df.columns=header
print(df) # df to print data
# Out:
#          date  temperature  wind speed weather
# 0  01-01-2019         37.0         6.0    Rain
# 1  02-01-2019         35.0         7.0   Sunny
# 2  03-01-2019         38.0         2.0    Snow
# 3  04-01-2019         34.0         7.0    Snow
# 4  05-01-2019         32.0         4.0    Rain
# 5  06-01-2019         31.0         2.0   Sunny
# 6           c          NaN         NaN     NaN
