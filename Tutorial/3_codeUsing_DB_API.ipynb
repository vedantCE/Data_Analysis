# %%
from dmodule import connect
#create connection object
connection=connect('databasename','username','password')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from dmodule import connect
#       2 #create connection object
#       3 connection=connect('databasename','username','password')
#
# ModuleNotFoundError: No module named 'dmodule'

# %%
#createing cursor object 
cursor=connection.cursor()

# %%
#run queries
cursor.execute("select * from tablename")
result=cursor.fetchall()

# %%
#free resources
cursor.close()
connection.close()
